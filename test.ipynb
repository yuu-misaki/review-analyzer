# %%
import main

url = "https://apps.apple.com/jp/app/google-%E3%82%A2%E3%83%97%E3%83%AA/id284815942?see-all=reviews"
csv_save_path = "result/google.csv"

main.run(csv_save_path = csv_save_path,url=url)
# Out:
# Scraped 10 reviews from https://apps.apple.com/jp/app/google-%E3%82%A2%E3%83%97%E3%83%AA/id284815942?see-all=reviews
